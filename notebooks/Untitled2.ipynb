# %%
import yfinance as yf
import pandas as pd
import scipy
from get_all_tickers import get_tickers as gt
from get_all_tickers.get_tickers import Region

# %%
import requests
import pandas as pd

headers = {
    'authority': 'api.nasdaq.com',
    'accept': 'application/json, text/plain, */*',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36',
    'origin': 'https://www.nasdaq.com',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.nasdaq.com/',
    'accept-language': 'en-US,en;q=0.9',
}

params = (
    ('tableonly', 'true'),
    ('limit', '25'),
    ('offset', '0'),
    ('download', 'true'),
)

resp = requests.get('https://api.nasdaq.com/api/screener/stocks', headers=headers, params=params)
data = resp.json()

# %%
stocks = data['data']['rows']

# %%
ticker = yf.Ticker(stocks[4]['symbol'])

# %%
ticker.quarterly_income_stmt.transpose()
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2023-06-30                         0.0                0.4         -910274.0
# 2023-03-31                         0.0                0.4         -818698.0
# 2022-12-31                         0.0             0.3001         -422315.0
# 2022-09-30                         0.0                0.4         -529434.0
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2023-06-30                                          -559584.0
# 2023-03-31                                           -27143.0
# 2022-12-31                                           607027.0
# 2022-09-30                                           122785.0
#
#               EBITDA      EBIT Net Interest Income Interest Income  \
# 2023-06-30 -910274.0 -910274.0            433066.0        433066.0
# 2023-03-31 -818698.0 -818698.0            974408.0        974408.0
# 2022-12-31 -422315.0 -422315.0           1289673.0       1289673.0
# 2022-09-30 -529434.0 -529434.0            797840.0        797840.0
#
#            Normalized Income  \
# 2023-06-30         -559584.0
# 2023-03-31          -27143.0
# 2022-12-31          607027.0
# 2022-09-30          122785.0
#
#            Net Income From Continuing And Discontinued Operation  ...  \
# 2023-06-30                                          -559584.0     ...
# 2023-03-31                                           -27143.0     ...
# 2022-12-31                                           607027.0     ...
# 2022-09-30                                           122785.0     ...
#
#            Net Non Operating Interest Income Expense  \
# 2023-06-30                                  433066.0
# 2023-03-31                                  974408.0
# 2022-12-31                                 1289673.0
# 2022-09-30                                  797840.0
#
#            Interest Income Non Operating Operating Income Operating Expense  \
# 2023-06-30                      433066.0        -910274.0          910274.0
# 2023-03-31                      974408.0        -818698.0          818698.0
# 2022-12-31                     1289673.0        -422315.0          422315.0
# 2022-09-30                      797840.0        -529434.0          529434.0
#
#            Other Operating Expenses Selling General And Administration  \
# 2023-06-30                 775911.0                           134363.0
# 2023-03-31                 790735.0                            27963.0
# 2022-12-31                 394352.0                            27963.0
# 2022-09-30                 501471.0                            27963.0
#
#            General And Administrative Expense Salaries And Wages  \
# 2023-06-30                           134363.0           134363.0
# 2023-03-31                            27963.0            27963.0
# 2022-12-31                            27963.0            27963.0
# 2022-09-30                            27963.0            27963.0
#
#            Total Revenue Operating Revenue
# 2023-06-30           0.0               0.0
# 2023-03-31           0.0               0.0
# 2022-12-31           0.0               0.0
# 2022-09-30           0.0               0.0
#
# [4 rows x 33 columns]
